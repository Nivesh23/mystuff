# %%
import pandas as pd

# %%
df=pd.read_csv("sample_data/amz_com-ecommerce_sample.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-7-e14a7d733086> in <module>
# ----> 1 df=pd.read_csv("sample_data/amz_com-ecommerce_sample.csv")
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import pandas as pd
data = pd.read_csv("sample_data/amz_com-ecommerce_sample.csv", encoding = 'unicode_escape')

# %%
data
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                              product_url  \
# 0      http://www.flipkart.com/alisha-solid-women-s-c...
# ...

# %%
df2=pd.read_csv("sample_data/flipkart_com-ecommerce_sample.csv",encoding="unicode_escape")

# %%
df2
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                              product_url  \
# 0      http://www.flipkart.com/alisha-solid-women-s-c...
# ...

# %%
df2.drop(['uniq_id','crawl_timestamp','product_url','product_category_tree','pid','image','is_FK_Advantage_product','description','product_rating','overall_rating','brand','product_specifications'],axis=1)
# Out:
#                       Product_name_in_Flipkart  Retail_Price_in_flipkart  \
# 0          Alisha Solid Women's Cycling Shorts                     999.0
# 1          FabHomeDecor Fabric Double Sofa Bed                   32157.0
# 2                                   AW Bellies                     999.0
# 3          Alisha Solid Women's Cycling Shorts                     699.0
# 4        Sicons All Purpose Arnica Dog Shampoo                     220.0
# ...                                        ...                       ...
# 19995           WallDesign Small Vinyl Sticker                    1500.0
# 19996  Wallmantra Large Vinyl Stickers Sticker                    1429.0
# 19997  Elite Collection Medium Acrylic Sticker                    1299.0
# 19998  Elite Collection Medium Acrylic Sticker                    1499.0
# 19999  Elite Collection Medium Acrylic Sticker                    1499.0
#
#        discounted_price_in_flipkart
# 0                             379.0
# ...

# %%
data.drop(['uniq_id','crawl_timestamp','product_url','product_category_tree','pid','image','is_FK_Advantage_product','description','product_rating','overall_rating','brand','product_specifications'],axis=1)
# Out:
#                                   product_name  retail_price  discounted_price
# 0          Alisha Solid Women's Cycling Shorts           982               438
# 1          FabHomeDecor Fabric Double Sofa Bed         32143             29121
# 2                                   AW Bellies           991               551
# 3          Alisha Solid Women's Cycling Shorts           694               325
# 4        Sicons All Purpose Arnica Dog Shampoo           208               258
# ...                                        ...           ...               ...
# 19995           WALLDESIGN SMALL VINYL STICKER          1498               876
# 19996  WALLMANTRA LARGE VINYL STICKERS STICKER          1415              1424
# 19997  ELITE COLLECTION MEDIUM ACRYLIC STICKER          1284              1196
# 19998  ELITE COLLECTION MEDIUM ACRYLIC STICKER          1492              1364
# 19999  ELITE COLLECTION MEDIUM ACRYLIC STICKER          1484              1247
#
# ...

# %%
df2.rename(columns = {'product_name':'Product_name_in_Flipkart','retail_price':'Retail_Price_in_flipkart','discounted_price':'discounted_price_in_flipkart'}, inplace = True)

# %%
df2.drop(['uniq_id','crawl_timestamp','product_url','product_category_tree','pid','image','is_FK_Advantage_product','description','product_rating','overall_rating','brand','product_specifications'],axis=1,inplace=True)

# %%
df2
# Out:
#                       Product_name_in_Flipkart  Retail_Price_in_flipkart  \
# 0          Alisha Solid Women's Cycling Shorts                     999.0
# 1          FabHomeDecor Fabric Double Sofa Bed                   32157.0
# 2                                   AW Bellies                     999.0
# 3          Alisha Solid Women's Cycling Shorts                     699.0
# 4        Sicons All Purpose Arnica Dog Shampoo                     220.0
# ...                                        ...                       ...
# 19995           WallDesign Small Vinyl Sticker                    1500.0
# 19996  Wallmantra Large Vinyl Stickers Sticker                    1429.0
# 19997  Elite Collection Medium Acrylic Sticker                    1299.0
# 19998  Elite Collection Medium Acrylic Sticker                    1499.0
# 19999  Elite Collection Medium Acrylic Sticker                    1499.0
#
#        discounted_price_in_flipkart
# 0                             379.0
# ...

# %%
data.drop(['uniq_id','crawl_timestamp','product_url','product_category_tree','pid','image','is_FK_Advantage_product','description','product_rating','overall_rating','brand','product_specifications'],axis=1,inplace=True)

# %%
data.rename(columns = {'product_name':'Product_name_in_Amazon','retail_price':'Retail_Price_in_Amazon','discounted_price':'discounted_price_in_Amazon'}, inplace = True)

# %%
data
# Out:
#                         Product_name_in_Amazon  Retail_Price_in_Amazon  \
# 0          Alisha Solid Women's Cycling Shorts                     982
# 1          FabHomeDecor Fabric Double Sofa Bed                   32143
# 2                                   AW Bellies                     991
# 3          Alisha Solid Women's Cycling Shorts                     694
# 4        Sicons All Purpose Arnica Dog Shampoo                     208
# ...                                        ...                     ...
# 19995           WALLDESIGN SMALL VINYL STICKER                    1498
# 19996  WALLMANTRA LARGE VINYL STICKERS STICKER                    1415
# 19997  ELITE COLLECTION MEDIUM ACRYLIC STICKER                    1284
# 19998  ELITE COLLECTION MEDIUM ACRYLIC STICKER                    1492
# 19999  ELITE COLLECTION MEDIUM ACRYLIC STICKER                    1484
#
#        discounted_price_in_Amazon
# 0                             438
# 1                           29121
# ...

# %%
df4=pd.concat([df2,data],axis=1)
df4
# Out:
#                       Product_name_in_Flipkart  Retail_Price_in_flipkart  \
# 0          Alisha Solid Women's Cycling Shorts                     999.0
# 1          FabHomeDecor Fabric Double Sofa Bed                   32157.0
# 2                                   AW Bellies                     999.0
# 3          Alisha Solid Women's Cycling Shorts                     699.0
# 4        Sicons All Purpose Arnica Dog Shampoo                     220.0
# ...                                        ...                       ...
# 19995           WallDesign Small Vinyl Sticker                    1500.0
# 19996  Wallmantra Large Vinyl Stickers Sticker                    1429.0
# 19997  Elite Collection Medium Acrylic Sticker                    1299.0
# 19998  Elite Collection Medium Acrylic Sticker                    1499.0
# 19999  Elite Collection Medium Acrylic Sticker                    1499.0
#
#        discounted_price_in_flipkart                   Product_name_in_Amazon  \
# ...

# %%
df4.to_csv('finalproducts.csv')
